# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
# Out:
# C:\Users\i353922\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\i353922\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\i353922\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\i353922\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sklearn import datasets
# Out:
# C:\Users\i353922\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df_X,df_y = datasets.load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df_X,df_y,random_state=32)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print("Mean square error: %.2f" %mean_squared_error(y_test,y_pred))
# Out:
# Mean square error: 2898.61

# %%
print("R2 Score: %.2f" %r2_score(y_test,y_pred))
# Out:
# R2 Score: 0.47

# %%
X_test[:,2]
# Out:
# array([-0.00512814,  0.04013997, -0.03315126, -0.05794093, -0.01806189,
#         0.00564998,  0.06816308,  0.00349435,  0.04229559,  0.05954058,
#        -0.03099563,  0.07462995,  0.07678558, -0.05578531, -0.05578531,
#        -0.06979687, -0.02884001,  0.03690653, -0.01806189, -0.00943939,
#        -0.04069594, -0.0277622 , -0.02345095, -0.00620595, -0.04177375,
#        -0.00189471,  0.0519959 ,  0.12852056,  0.01427248,  0.12313149,
#         0.03043966, -0.00297252,  0.03367309, -0.04500719, -0.0105172 ,
#        -0.00405033,  0.00349435,  0.00564998, -0.0374625 , -0.04500719,
#         0.02720622, -0.03530688,  0.01427248, -0.01159501, -0.02021751,
#         0.0250506 ,  0.04984027, -0.0374625 ,  0.02397278,  0.03259528,
#        -0.03099563, -0.01806189,  0.02181716,  0.00996123, -0.03099563,
#        -0.00189471, -0.02345095,  0.00672779,  0.00996123,  0.04121778,
#         0.07355214,  0.01858372,  0.09295276, -0.0730303 , -0.02452876,
# ...

# %%
plt.figure(figsize=(8,5))
plt.scatter(X_test[:,2],y_test)
plt.plot(X_test[:,2],y_pred,linewidth=2)
